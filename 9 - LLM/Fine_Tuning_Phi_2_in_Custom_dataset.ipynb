# %% [markdown]
# # Installing Library

# %%
# !pip install -q torch peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 accelerate einops tqdm scipy
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 31.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.2 MB/s eta 0:00:00

# %% [markdown]
# # Loading Library

# %%
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig,
    TrainingArguments,
    HfArgumentParser,
    TrainingArguments,
    )

import torch, os
from dataclasses import dataclass, field
from typing import Optional
import pandas as pd
from datasets import load_dataset, load_from_disk
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
from huggingface_hub import interpreter_login
from tqdm.notebook import tqdm
from trl import SFTTrainer

# %%
# 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
interpreter_login()
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %% [markdown]
# # Loading Data

# %%
from datasets import load_dataset

ds = load_dataset("Amod/mental_health_counseling_conversations", split='train')
ds
# Out:
# README.md:   0%|          | 0.00/2.82k [00:00<?, ?B/s]
# combined_dataset.json:   0%|          | 0.00/4.79M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3512 [00:00<?, ? examples/s]
# Dataset({
#     features: ['Context', 'Response'],
#     num_rows: 3512
# })

# %%
data = pd.DataFrame(ds)
data.head()
# Out:
#                                              Context  \
# 0  I'm going through some things with my feelings...
# 1  I'm going through some things with my feelings...
# 2  I'm going through some things with my feelings...
# 3  I'm going through some things with my feelings...
# 4  I'm going through some things with my feelings...
#
#                                             Response
# 0  If everyone thinks you're worthless, then mayb...
# 1  Hello, and thank you for your question and see...
# 2  First thing I'd suggest is getting the sleep y...
# 3  Therapy is essential for those that are feelin...
# 4  I first want to let you know that you are not ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3512 entries, 0 to 3511
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Context   3512 non-null   object
#  1   Response  3512 non-null   object
# dtypes: object(2)
# memory usage: 55.0+ KB

# %% [markdown]
# # Prepare Dataset

# %%
def reforamt_data(row):
  question = row['Context']
  answer = row['Response']
  formated_string =  f"[INST]: {question}\n[/INST]: {answer}"
  return formated_string

data['Text'] = data.apply(reforamt_data, axis=1)
data.head()
# Out:
#                                              Context  \
# 0  I'm going through some things with my feelings...
# 1  I'm going through some things with my feelings...
# 2  I'm going through some things with my feelings...
# 3  I'm going through some things with my feelings...
# 4  I'm going through some things with my feelings...
#
#                                             Response  \
# 0  If everyone thinks you're worthless, then mayb...
# 1  Hello, and thank you for your question and see...
# 2  First thing I'd suggest is getting the sleep y...
# 3  Therapy is essential for those that are feelin...
# 4  I first want to let you know that you are not ...
#
#                                                 Text
# 0  [INST]: I'm going through some things with my ...
# 1  [INST]: I'm going through some things with my ...
# 2  [INST]: I'm going through some things with my ...
# 3  [INST]: I'm going through some things with my ...
# 4  [INST]: I'm going through some things with my ...

# %%
new_data = data[['Text']]
new_data.head()
# Out:
#                                                 Text
# 0  [INST]: I'm going through some things with my ...
# 1  [INST]: I'm going through some things with my ...
# 2  [INST]: I'm going through some things with my ...
# 3  [INST]: I'm going through some things with my ...
# 4  [INST]: I'm going through some things with my ...

# %%
new_data.to_csv('/content/data.csv', index=False)

# %% [markdown]
# # Loading New data

# %%
training_dataset = load_dataset('csv', data_files='/content/data.csv', split='train')
training_dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['Text'],
#     num_rows: 3512
# })

# %% [markdown]
# # Prepare Arguments & Parameters

# %%
base_model = 'microsoft/phi-2'
new_model = 'phi-2-mental-health'

tokenizer = AutoTokenizer.from_pretrained(base_model, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = 'right'
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/7.34k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]

# %% [markdown]
# # Prepare LoRA & BNB

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)


model = AutoModelForCausalLM.from_pretrained(
    base_model,
    quantization_config=bnb_config,
    trust_remote_code=True,
    flash_attn=True,
    flash_rotary=True,
    fused_dense=True,
    low_cpu_mem_usage=True,
    device_map={'': 0},
    revision='refs/pr/23'
)

model.config.use_cache = False
model.config.pretraining_tp = 1


model = prepare_model_for_kbit_training(model, use_gradient_checkpointing=True)
# Out:
# config.json:   0%|          | 0.00/755 [00:00<?, ?B/s]
# configuration_phi.py:   0%|          | 0.00/2.03k [00:00<?, ?B/s]
# modeling_phi.py:   0%|          | 0.00/33.7k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/24.3k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/577M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# generation_config.json:   0%|          | 0.00/69.0 [00:00<?, ?B/s]

# %% [markdown]
# # Building Training Arguments

# %%
training_Arguments = TrainingArguments(
    output_dir='./mhGPT',
    num_train_epochs=2,
    per_device_train_batch_size=2,
    gradient_accumulation_steps=32,
    evaluation_strategy='steps',
    eval_steps=1500,
    optim="paged_adamw_32bit",
    save_steps=1500,
    warmup_ratio=0.05,
    logging_steps=15,
    learning_rate=2e-4,
    weight_decay=0.001,
    max_steps=-1,
    lr_scheduler_type='cosine'
)


peft_config = LoraConfig(
    lora_alpha=64,
    lora_dropout=0.05,
    r=32,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=[
        "Wqkv",
        "fc1",
        "fc2"
        ]
)


trainer = SFTTrainer(
    model=model,
    train_dataset=training_dataset,
    peft_config=peft_config,
    dataset_text_field="Text",
    max_seq_length=690,
    tokenizer=tokenizer,
    args=training_Arguments,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/3512 [00:00<?, ? examples/s]

# %% [markdown]
# # Training Model

# %%
trainer.train()
# a217c8ee8e6ec53eea11fd64e5033644487210f5
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/content/wandb/run-20241019_155750-skxeka8p</code>
# Syncing run <strong><a href='https://wandb.ai/asdasdosama111/huggingface/runs/skxeka8p' target="_blank">solar-meadow-43</a></strong> to <a href='https://wandb.ai/asdasdosama111/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
# ...

# %% [markdown]
# #
